# %%
import pandas as pd

# %%
file_name = "../Data Sharing_FIU_v9_2022-12-29_pr.xlsx"

# %%
data_sheets = pd.read_excel(file_name, sheet_name=None)

# %%
field_names = []
for sheet in data_sheets.items():
    columns = sheet[1].columns
    sheet_name = sheet[0]
    for column in columns:
        field_names.append([column, sheet_name])

# %%
all_fields = pd.DataFrame(field_names)
all_fields.columns = ["Variable / Field Name", "File Name"]
print(f"Number of variables: {all_fields.shape[0]}")
# Out:
# Number of variables: 148

# %%
all_fields.head()
# Out:
#     Variable / Field Name               File Name
# 0             protocol_id  Technology Description
# 1     technology_platform  Technology Description
# 2  technology_description  Technology Description
# 3    technology_reference  Technology Description
# 4            analyte_type  Technology Description

# %%
all_fields.tail(50)
# Out:
#                     Variable / Field Name            File Name
# 98                               headache     Clinical Samples
# 99                            muscle_ache     Clinical Samples
# 100            new_loss_of_taste_or_smell     Clinical Samples
# 101                                chills     Clinical Samples
# 102                     excessive_fatigue     Clinical Samples
# 103                       nausea_vomiting     Clinical Samples
# 104                              diarrhea     Clinical Samples
# 105                        abdominal_pain     Clinical Samples
# 106                             skin_rash     Clinical Samples
# 107                        conjunctivitis     Clinical Samples
# 108                           height_feet     Clinical Samples
# 109                         height_inches     Clinical Samples
# 110                            weight_lbs     Clinical Samples
# 111                         health_status     Clinical Samples
# 112                              study_id         Test Results
# 113                           protocol_id         Test Results
# 114                             cohort_id         Test Results
# 115                   technology_platform         Test Results
# 116                          analyte_type         Test Results
# 117                     voc_specimen_type         Test Results
# 118                               peak_id         Test Results
# 119           voc_compound_retention_time         Test Results
# 120      voc_compound_retention_time_unit         Test Results
# 121                voc_relative_abundance         Test Results
# 122                     voc_compound_name         Test Results
# 123                  voc_compound_formula         Test Results
# 124                 voc_compound_inchikey         Test Results
# 125                          assay_result         Test Results
# 126                           protocol_id  Performance Metrics
# 127                   technology_platform  Performance Metrics
# 128                             cohort_id  Performance Metrics
# 129                           cohort_size  Performance Metrics
# 130                      positive_samples  Performance Metrics
# 131                      negative_samples  Performance Metrics
# 132                       validation_test  Performance Metrics
# 133          validation_test_permutations  Performance Metrics
# 134        positive_samples_in_calulation  Performance Metrics
# 135      positive_samples_in_calulation.1  Performance Metrics
# 136                    clincal_sensitivty  Performance Metrics
# 137         clincal_sensitivty_ci_percent  Performance Metrics
# 138             clincal_sensitivty_ci_min  Performance Metrics
# 139             clincal_sensitivty_ci_max  Performance Metrics
# 140             positive_predicitve_value  Performance Metrics
# 141  positive_predicitve_value_ci_percent  Performance Metrics
# 142      positive_predicitve_value_ci_min  Performance Metrics
# 143      positive_predicitve_value_ci_max  Performance Metrics
# 144             negative_predicitve_value  Performance Metrics
# 145  negative_predicitve_value_ci_percent  Performance Metrics
# 146      negative_predicitve_value_ci_min  Performance Metrics
# 147      negative_predicitve_value_ci_max  Performance Metrics
