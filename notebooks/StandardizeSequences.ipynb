# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Exosome/Das/rad_018_780-01_v001/rad_018_780-01_DATA_PrimerSet_v001.csv", dtype=str)

# %%
df.head()
# Out:
#               primer_set_id                primer_sequence  \
# 0  COVID response microRNAs    AUCAGGGCUUGUGGAAUGGGAAGAAAA
# 1  COVID response microRNAs  GGGAGAAGGGUCGGGGCTTTTTTTAAAAA
# 2  COVID response microRNAs           AGGAGAAGUAAAGUAGAAAA
# 3  COVID response microRNAs      CAGAUCAUGGGACUGUCUCAGATAA
# 4  COVID response microRNAs       UGGGUGGUCUGGAGAUUUGUGCAA
#
#   target_analyte_name target_analyte_region target_analyte_id  \
# 0     hsa-miR-3127-3p              microRNA      MIMAT0019201
# 1        hsa-miR-4516              microRNA      MIMAT0019053
# 2        hsa-miR-4434              microRNA      MIMAT0018950
# 3        hsa-miR-5694              microRNA      MIMAT0022487
# 4        hsa-miR-1293              microRNA      MIMAT0005883
#
#    target_analyte_sequence                       target_analyte_url  \
# 0  AUCAGGGCUUGUGGAAUGGGAAG  https://mirbase.org/mature/MIMAT0019201
# 1        GGGAGAAGGGUCGGGGC  https://mirbase.org/mature/MIMAT0019053
# 2       AGGAGAAGUAAAGUAGAA  https://mirbase.org/mature/MIMAT0018950
# 3    CAGAUCAUGGGACUGUCUCAG  https://mirbase.org/mature/MIMAT0022487
# 4   UGGGUGGUCUGGAGAUUUGUGC  https://mirbase.org/mature/MIMAT0005883
#
#      analyte_type target_organism_name target_organism_taxonomy_id
# 0  human microRNA                human                        9606
# 1  human microRNA                human                        9606
# 2  human microRNA                human                        9606
# 3  human microRNA                human                        9606
# 4  human microRNA                human                        9606

# %%
df["target_organism_taxonomy_id"] = df["target_organism_taxonomy_id"].astype(str)
df["target_organism_taxonomy_id"] = df["target_organism_taxonomy_id"].str.replace(".0","")
df["target_analyte_sequence"] = df["target_analyte_sequence"].str.upper()
df["target_analyte_sequence"] = "5'-" + df["target_analyte_sequence"] + "-3'"
df["primer_sequence"] = df["primer_sequence"].str.upper()
df["primer_sequence"] = "5'-" + df["primer_sequence"] + "-3'"
df.dropna(how='all', inplace=True)
df.dropna(how='all', axis=1, inplace=True)

# %%
df.head()
# Out:
#               primer_set_id                      primer_sequence  \
# 0  COVID response microRNAs    5'-AUCAGGGCUUGUGGAAUGGGAAGAAAA-3'
# 1  COVID response microRNAs  5'-GGGAGAAGGGUCGGGGCTTTTTTTAAAAA-3'
# 2  COVID response microRNAs           5'-AGGAGAAGUAAAGUAGAAAA-3'
# 3  COVID response microRNAs      5'-CAGAUCAUGGGACUGUCUCAGATAA-3'
# 4  COVID response microRNAs       5'-UGGGUGGUCUGGAGAUUUGUGCAA-3'
#
#   target_analyte_name target_analyte_region target_analyte_id  \
# 0     hsa-miR-3127-3p              microRNA      MIMAT0019201
# 1        hsa-miR-4516              microRNA      MIMAT0019053
# 2        hsa-miR-4434              microRNA      MIMAT0018950
# 3        hsa-miR-5694              microRNA      MIMAT0022487
# 4        hsa-miR-1293              microRNA      MIMAT0005883
#
#          target_analyte_sequence                       target_analyte_url  \
# 0  5'-AUCAGGGCUUGUGGAAUGGGAAG-3'  https://mirbase.org/mature/MIMAT0019201
# 1        5'-GGGAGAAGGGUCGGGGC-3'  https://mirbase.org/mature/MIMAT0019053
# 2       5'-AGGAGAAGUAAAGUAGAA-3'  https://mirbase.org/mature/MIMAT0018950
# 3    5'-CAGAUCAUGGGACUGUCUCAG-3'  https://mirbase.org/mature/MIMAT0022487
# 4   5'-UGGGUGGUCUGGAGAUUUGUGC-3'  https://mirbase.org/mature/MIMAT0005883
#
#      analyte_type target_organism_name target_organism_taxonomy_id
# 0  human microRNA                human                        9606
# 1  human microRNA                human                        9606
# 2  human microRNA                human                        9606
# 3  human microRNA                human                        9606
# 4  human microRNA                human                        9606

# %%
df.to_csv("../data/Exosome/Das/rad_018_780-01_v001/rad_018_780-01_DATA_PrimerSet_v001_pr.csv", index=False)
