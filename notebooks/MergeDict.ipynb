# %% [markdown]
# # Merges two data dictionaries

# %%
import pandas as pd

# %%
filename1 = "../data/Exosome/Wong/EFIRM_NAB_2023-01-11/EFIRM Neutralizing Antibody_U18_UCLA_2023_01_11 - without IDs_DICT.csv"
filename2 = "../data/Exosome/Wong/SERS_2013-01-14/SERS template_1_13_2023_pr3_DICT.csv"
filename = "../data/Exosome/Wong/EFIRM_NAB_SERS_2023-01-14/EFIRM_NAB_SERS_2023-01-14_DICT.csv"

# %%
df1 = pd.read_csv(filename1, keep_default_na=False,)
print(f"{filename1} dimensions: {df1.shape}")
df1.head()
# Out:
# ../data/Exosome/Wong/EFIRM_NAB_2023-01-11/EFIRM Neutralizing Antibody_U18_UCLA_2023_01_11 - without IDs_DICT.csv dimensions: (161, 12)
#   Variable / Field Name Section Header Field Type  \
# 0              study_id       Identity       text
# 1                  race           Race   checkbox
# 2             ethnicity      Ethnicity      radio
# 3                   age            Age    integer
# 4                   sex            Sex      radio
#
#                                       Field Label  \
# 0      RADx-rad Study ID; Subject ID; Datavent ID
# 1      What is your race? Mark one or more boxes.
# 2           Are you of Hispanic or Latino origin?
# 3                               What is your age?
# 4  What is your biological sex assigned at birth?
#
#              Choices, Calculations, OR Slider Labels  \
# 0
# 1  1, American Indian or Alaska Native | 2, Asian...
# 2  1, Yes, of Hispanic or Latino origin | 0, No, ...
# 3
# 4  1, Male | 2, Female | 3, Intersex | 4, None of...
#
#                                           Field Note  \
# 0
# 1
# 2
# 3  Age in years. For babies less than 1 year old,...
# 4
#
#   Text Validation Type OR Show Slider Number Text Validation Min  \
# 0
# 1
# 2
# 3                                                              0
# 4
#
#   Text Validation Max Branching Logic (Show field only if...) Unit  \
# 0
# 1
# 2
# 3                  90
# 4
#
#           CDE Reference
# 0  RADx-rad Minimum CDE
# 1  RADx-rad Minimum CDE
# 2  RADx-rad Minimum CDE
# 3  RADx-rad Minimum CDE
# 4  RADx-rad Minimum CDE

# %%
df2 = pd.read_csv(filename2, keep_default_na=False,)
print(f"{filename1} dimensions: {df2.shape}")
df2.head()
# Out:
# ../data/Exosome/Wong/EFIRM_NAB_2023-01-11/EFIRM Neutralizing Antibody_U18_UCLA_2023_01_11 - without IDs_DICT.csv dimensions: (141, 12)
#   Variable / Field Name Section Header Field Type  \
# 0              study_id       Identity       text
# 1                  race           Race   checkbox
# 2             ethnicity      Ethnicity      radio
# 3                   age            Age    integer
# 4                   sex            Sex      radio
#
#                                       Field Label  \
# 0      RADx-rad Study ID; Subject ID; Datavent ID
# 1      What is your race? Mark one or more boxes.
# 2           Are you of Hispanic or Latino origin?
# 3                               What is your age?
# 4  What is your biological sex assigned at birth?
#
#              Choices, Calculations, OR Slider Labels  \
# 0
# 1  1, American Indian or Alaska Native | 2, Asian...
# 2  1, Yes, of Hispanic or Latino origin | 0, No, ...
# 3
# 4  1, Male | 2, Female | 3, Intersex | 4, None of...
#
#                                           Field Note  \
# 0
# 1
# 2
# 3  Age in years. For babies less than 1 year old,...
# 4
#
#   Text Validation Type OR Show Slider Number Text Validation Min  \
# 0
# 1
# 2
# 3                                                              0
# 4
#
#   Text Validation Max Branching Logic (Show field only if...) Unit  \
# 0
# 1
# 2
# 3                  90
# 4
#
#           CDE Reference
# 0  RADx-rad Minimum CDE
# 1  RADx-rad Minimum CDE
# 2  RADx-rad Minimum CDE
# 3  RADx-rad Minimum CDE
# 4  RADx-rad Minimum CDE

# %%
df = pd.concat([df1, df2])
df.drop_duplicates(df, inplace=True)
print(f" dimensions: {df.shape}")
# Out:
#  dimensions: (209, 12)

# %%
print(f"{filename1} dimensions: {df.shape}")
df.head(1000)
# Out:
# ../data/Exosome/Wong/EFIRM_NAB_2023-01-11/EFIRM Neutralizing Antibody_U18_UCLA_2023_01_11 - without IDs_DICT.csv dimensions: (209, 12)
#                Variable / Field Name                   Section Header  \
# 0                           study_id                         Identity
# 1                               race                             Race
# 2                          ethnicity                        Ethnicity
# 3                                age                              Age
# 4                                sex                              Sex
# ..                               ...                              ...
# 118  non_clinical_specificity_ci_min           Analytical Performance
# 119  non_clinical_specificity_ci_max           Analytical Performance
# 120    analytical_cutoff_description             Clinical Performance
# 121            analytical_cutoff_min             Clinical Performance
# 124                       true_label  Analytical/Clinical Performance
#
#     Field Type                                        Field Label  \
# 0         text         RADx-rad Study ID; Subject ID; Datavent ID
# 1     checkbox         What is your race? Mark one or more boxes.
# 2        radio              Are you of Hispanic or Latino origin?
# 3      integer                                  What is your age?
# 4        radio     What is your biological sex assigned at birth?
# ..         ...                                                ...
# 118      float  Lower bound of confidence interval for non_cli...
# 119      float  Upper bound of confidence interval for non_cli...
# 120       text               Description of the analytical cutoff
# 121      float  Test is considered positive if assay readout i...
# 124   category       The expected label based on a  gold standard
#
#                Choices, Calculations, OR Slider Labels  \
# 0
# 1    1, American Indian or Alaska Native | 2, Asian...
# 2    1, Yes, of Hispanic or Latino origin | 0, No, ...
# 3
# 4    1, Male | 2, Female | 3, Intersex | 4, None of...
# ..                                                 ...
# 118
# 119
# 120
# 121
# 124                 positive | negative | inconclusive
#
#                                             Field Note  \
# 0
# 1
# 2
# 3    Age in years. For babies less than 1 year old,...
# 4
# ..                                                 ...
# 118
# 119
# 120
# 121
# 124
#
#     Text Validation Type OR Show Slider Number Text Validation Min  \
# 0
# 1
# 2
# 3                                                                0
# 4
# ..                                         ...                 ...
# 118
# 119
# 120
# 121
# 124
#
#     Text Validation Max Branching Logic (Show field only if...) Unit  \
# 0
# 1
# 2
# 3                    90
# 4
# ..                  ...                                     ...  ...
# 118
# 119
# 120
# 121
# 124
#
#                                          CDE Reference
# 0                                 RADx-rad Minimum CDE
# 1                                 RADx-rad Minimum CDE
# 2                                 RADx-rad Minimum CDE
# 3                                 RADx-rad Minimum CDE
# 4                                 RADx-rad Minimum CDE
# ..                                                 ...
# 118  RADx-rad DCC|https://www.medcalc.org/calc/diag...
# 119  RADx-rad DCC|https://www.medcalc.org/calc/diag...
# 120                                       RADx-rad DCC
# 121                                       RADx-rad DCC
# 124                                       RADx-rad DCC
#
# [209 rows x 12 columns]

# %%
df.to_csv(filename, index=False)
